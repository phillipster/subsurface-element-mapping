# %% [markdown]
# <a href="https://colab.research.google.com/github/phillipster/subsurface-element-mapping/blob/main/S24_Summer_Church_Nearby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
API_KEY = 'AIzaSyBbPzmWZUvD58nBY9HY1i0gAzlh2QpqsLo'

import requests
import pandas as pd

# %%
import requests
import time
location = '40.752301	,-73.799000	'
radius = 500
place_type = 'church'
places = []

def fetch_all_places(api_key, location, radius, place_type):
    # Google Places API endpoint
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # Initial parameters for the API request
    params = {
        'key': API_KEY,
        'location': location,
        'radius': radius,
        'type': place_type
    }

    # List to store all places

    while True:
        # Make the API request
        response = requests.get(url, params=params)
        res = response.json()

        # Check if the request was successful
        if res['status'] == 'OK':
            # Extract places
            places.extend([(place['name'], place['vicinity']) for place in res['results']])

            # Check for the presence of a 'next_page_token' in the response
            if 'next_page_token' in res:
                params['pagetoken'] = res['next_page_token']
            else:
                break  # No more pages to fetch

            # Important: There is a short delay needed between requests for the next page token to become valid
            time.sleep(10)
        else:
            print("Failed to fetch results:", res['status'])
            break

    return places

# Example usage:
api_key = API_KEY  # Replace 'YOUR_API_KEY' with your actual Google Cloud API key
location = '40.752301	,-73.799000	'
radius = 500
place_type = 'church'

# Fetch all churches
churches = fetch_all_places(api_key, location, radius, place_type)
for name, vicinity in churches:
    print(f"Name: {name}, Location: {vicinity}")
# Out:
# Counter:  1
# Name: Trinity Church, Address: 89 Broadway, New York
# Counter:  2
# Name: St. Paul's Chapel, Address: 209 Broadway, New York
# Counter:  3
# Name: St Peter's Roman Catholic Church, Address: 22 Barclay Street, New York
# Counter:  4
# Name: St. Andrew Roman Catholic Church, Address: 20 Cardinal Hayes Place, New York
# Counter:  5
# Name: Our Lady of Victory Church, Address: 22 Barclay Street, New York
# Counter:  6
# Name: St. Elizabeth Ann Seton Shrine, Address: 7 State Street, New York
# Counter:  7
# Name: RCM Group, Address: 355 South End Avenue, New York
# Counter:  8
# Name: Revival Partners LLC, Address: 355 South End Avenue, New York
# Counter:  9
# Name: Liberty Church New York City, Address: 55 Broadway, New York
# Counter:  10
# Name: St. Nicholas National Shrine, Address: 130 Liberty Street, New York
# Counter:  11
# Name: Faith Evangelistic Ministries, Address: kt # 2, New York
# Counter:  12
# Name: River NYC Church, Address: 75 Murray Street, New York
# Counter:  13
# Name: Kingdom Hall of Jehovah's Witnesses, Address: 336 Pearl Street, New York
# Counter:  14
# Name: Rev. Christie Hord, Address: 111 Broadway, New York
# Counter:  15
# Name: jesus week nyc, Address: 2 Washington Street, New York
# Counter:  16
# Name: A New Heritage of Giving, Address: 120 Wall Street, New York
# Counter:  17
# Name: Our Lady of the Rosary, Address: 7 State Street, New York
# Counter:  18
# Name: Orthodox Union, Address: 40 Rector Street, New York
# Counter:  19
# Name: Wall Street Synagogue, Address: 47 Beekman Street, New York
# Counter:  20
# Name: John Street United Methodist Church, Address: 44 John Street, New York

# %%
location = '40.752301	,-73.799000	'
radius = 500
place_type = 'church'

url = (
    f'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
    f'?location={location}'
    f'&radius={radius}'
    f'&type={place_type}'
    f'&key={API_KEY}'
)

response = requests.get(url)

places = response.json()
counter = 0
if places['status'] == 'OK':
    for place in places['results']:
        name = place['name']
        address = place.get('vicinity', 'No address available')
        counter += 1
        print("Counter: ",counter)
        print(f'Name: {name}, Address: {address}')
else:
    print(f"Error: {places['status']}")
# Out:
#                                    Name                            Address  \
# 0                        Trinity Church              89 Broadway, New York
# 1                     St. Paul's Chapel             209 Broadway, New York
# 2      St Peter's Roman Catholic Church        22 Barclay Street, New York
# 3      St. Andrew Roman Catholic Church  20 Cardinal Hayes Place, New York
# 4            Our Lady of Victory Church        22 Barclay Street, New York
# 5        St. Elizabeth Ann Seton Shrine           7 State Street, New York
# 6                             RCM Group     355 South End Avenue, New York
# 7                  Revival Partners LLC     355 South End Avenue, New York
# 8          Liberty Church New York City              55 Broadway, New York
# 9          St. Nicholas National Shrine       130 Liberty Street, New York
# 10        Faith Evangelistic Ministries                   kt # 2, New York
# 11                     River NYC Church         75 Murray Street, New York
# 12  Kingdom Hall of Jehovah's Witnesses         336 Pearl Street, New York
# 13                   Rev. Christie Hord             111 Broadway, New York
# 14                       jesus week nyc      2 Washington Street, New York
# 15             A New Heritage of Giving          120 Wall Street, New York
# 16               Our Lady of the Rosary           7 State Street, New York
# 17                       Orthodox Union         40 Rector Street, New York
# 18                Wall Street Synagogue        47 Beekman Street, New York
# 19  John Street United Methodist Church           44 John Street, New York
#
#      Latitude  Longitude
# 0   40.707893 -74.011790
# 1   40.711328 -74.009183
# 2   40.712483 -74.009531
# 3   40.713344 -74.002662
# 4   40.706969 -74.008875
# 5   40.702559 -74.013774
# 6   40.710943 -74.016333
# 7   40.710503 -74.016620
# 8   40.706837 -74.012999
# 9   40.710134 -74.013203
# 10  40.708043 -74.007242
# 11  40.714827 -74.010554
# 12  40.709147 -74.001625
# 13  40.708687 -74.011505
# 14  40.705655 -74.015630
# 15  40.704751 -74.006027
# 16  40.702559 -74.013774
# 17  40.708428 -74.014726
# 18  40.710047 -74.005512
# 19  40.709175 -74.008073

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install openpyxl

import pandas as pd

file_path = '/content/drive/MyDrive/Colab Notebooks/Cemeteries in NYC.xlsx'

df = pd.read_excel(file_path)
len(df)
# Out:
# 20

# %%
df
# extract the columns important
df_filtered = df[['Name', 'Still Exists?', 'Coordinates']]
df_filtered
# Filter the DataFrame based on 'Exist or Not' status
df_exist = df_filtered[df_filtered['Still Exists?'] == 'Yes']  # or whatever the value indicating existence


# Display the filtered DataFrame
df_exist
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-38d5a91ac6e9> in <cell line: 1>()
# ----> 1 df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Cemeteries in NYC.xlsx')
#       2
#       3 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# --> 478         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479     elif engine and engine != io.engine:
#     480         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1494                 ext = "xls"
#    1495             else:
# -> 1496                 ext = inspect_excel_format(
#    1497                     content_or_path=path_or_buffer, storage_options=storage_options
#    1498                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1369         content_or_path = BytesIO(content_or_path)
#    1370
# -> 1371     with get_handle(
#    1372         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1373     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     866         else:
#     867             # Binary mode
# --> 868             handle = open(handle, ioargs.mode)
#     869         handles.append(handle)
#     870
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/Cemeteries in NYC.xlsx'

# %%
# Coordinate conversion
df_exist['Coordinates'] = df_exist['Coordinates'].astype(str)

# Function to convert coordinates
def convert_coordinates(coord):
    try:
        lon, lat = coord.split()

        # Convert longitude
        if 'W' in lon:
            lon = -float(lon.replace('°W', ''))
        elif 'E' in lon:
            lon = float(lon.replace('°E', ''))

        # Convert latitude
        if 'S' in lat:
            lat = -float(lat.replace('°S', ''))
        elif 'N' in lat:
            lat = float(lat.replace('°N', ''))

        return lon, lat
    except ValueError as e:
        print(f"Error processing coordinate: '{coord}'. Error: {e}")
        return None, None

# Apply function to split coordinates
df_exist[['Longitude', 'Latitude']] = df_exist['Coordinates'].apply(lambda x: pd.Series(convert_coordinates(x)))

# Drop the original 'Coordinates' column if needed
# df.drop(columns=['Coordinates'], inplace=True)

# Display the DataFrame
df_exist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35273016959b> in <cell line: 2>()
#       1 # Coordinate conversion
# ----> 2 df_exist['Coordinates'] = df_exist['Coordinates'].astype(str)
#       3
#       4 # Function to convert coordinates
#       5 def convert_coordinates(coord):
#
# NameError: name 'df_exist' is not defined

# %%
df_copy = df_exist.copy()
print("df_copy: ")
df_copy['Number of Churches Nearby'] = 0  # Initialize with 0 or any suitable default value
print(df_copy)

print("df_exist: ")
df_exist['Longitude']
# Out:
# Updated row 1/189
# Updated row 2/189
# Updated row 3/189
# Updated row 4/189
# Updated row 5/189
# Updated row 6/189
# Updated row 7/189
# Updated row 8/189
# Updated row 9/189
# Updated row 10/189
# Updated row 11/189
# Updated row 12/189
# Updated row 13/189
# Updated row 14/189
# Updated row 15/189
# Updated row 16/189
# Updated row 17/189
# Updated row 18/189
# Updated row 19/189
# Updated row 20/189
# Updated row 21/189
# Updated row 22/189
# Updated row 23/189
# Updated row 24/189
# Updated row 25/189
# Updated row 26/189
# Updated row 27/189
# Updated row 28/189
# Updated row 29/189
# Updated row 30/189
# Updated row 31/189
# Updated row 32/189
# Updated row 33/189
# Updated row 34/189
# Updated row 35/189
# Updated row 36/189
# Updated row 37/189
# Updated row 38/189
# Updated row 39/189
# Updated row 40/189
# Updated row 41/189
# Updated row 42/189
# Updated row 43/189
# Updated row 44/189
# Updated row 45/189
# Updated row 46/189
# Updated row 47/189
# Updated row 48/189
# Updated row 49/189
# Updated row 50/189
# Updated row 51/189
# Updated row 52/189
# Updated row 53/189
# Updated row 54/189
# Updated row 55/189
# Updated row 56/189
# Updated row 57/189
# Updated row 58/189
# Updated row 59/189
# Updated row 60/189
# Updated row 61/189
# Updated row 62/189
# Updated row 63/189
# Updated row 64/189
# 36     21
# 37     60
# 38     60
# 39     15
# 40     22
# 41     23
# 42     19
# 43     44
# 44     51
# 45     60
# 46     37
# 47     60
# 48     60
# 49     14
# 50      0
# 51     49
# 52      0
# 53      8
# 54     50
# 55      9
# 56      6
# 57     60
# 58     16
# 59     60
# 60      6
# 61     60
# 62     19
# 63     19
# 64     60
# 65     36
# 66      3
# 67      4
# 68     60
# 69     26
# 70     33
# 71     33
# 72     30
# 73      5
# 74     38
# 75      5
# 76      9
# 77     60
# 78     60
# 79      1
# 80     23
# 81     45
# 82     60
# 83     47
# 84     59
# 85     13
# 86     50
# 87     60
# 88     15
# 89     55
# 90     60
# 91     60
# 92     60
# 93      0
# 94     60
# 95     54
# 96      3
# 97     43
# 98     44
# 99     60
# 100    42
# 101     2
# 102    60
# 103    60
# 104    16
# 105    14
# 106     6
# 107     1
# 108     3
# 109     8
# 110     8
# 111    12
# 112     8
# 113     9
# 114    19
# 115    31
# 116    60
# 117    60
# 118    60
# 119    60
# 120    60
# 121    60
# 122    24
# 123    42
# 124    23
# 125    60
# 126    14
# 127    60
# 128    27
# 129    60
# 130     7
# 131    10
# 132    29
# 133     3
# 134     3
# 135     1
# 136    12
# 137    56
# 138     6
# 139     6
# 140     6
# 141     6
# 142     3
# 143    40
# 144     4
# 145    17
# 146    60
# 147    17
# 148    10
# 149    60
# 150    60
# 151    39
# 152    36
# 153    14
# 154    33
# 155    16
# 156    60
# 157     0
# 158     5
# 159     8
# 160     8
# 161    60
# 162    16
# 163    12
# 164     4
# 165    27
# 166    15
# 167    20
# 168    11
# 169    42
# 170    40
# 171    41
# 172    13
# 173    40
# 174    60
# 175    60
# 176    43
# 177    60
# 178    60
# 179    60
# 180    26
# 181    60
# 182     7
# 183    35
# 184    15
# 185    18
# 186    53
# 187    34
# 188    30
#                                                   Name  \
# 0                              Shaaray Tefila Cemetery
# 1                        Brick Presbyterian Churchyard
# 2                         St. Andrew's Church Cemetery
# 3                                     Luyster Cemetery
# 4                          Bergen Family Burial ground
# 5    41St Street Reformed Presbyterian Church Cemetery
# 6         Port Richmond Reformed Dutch Church Cemetery
# 7                                    Lutheran Cemetery
# 8     First Reformed Dutch Church of Brooklyn cemetery
# 9                                     Melrose Cemetery
# 10   Attorney Street Methodist Protestant Church Bu...
# 11                                 Ocean View Cemetery
# 12                             Thorne-Wilkins Cemetery
# 13                       Public Burial Ground,Brooklyn
# 14                  Public Burial Ground, Fordham Road
# 15     Fordham Manor Church Cemetery, Kingsbridge Road
# 16   Bedford Street Methodist Church Graveyard and ...
# 17                              Mount Loretto Cemetery
# 18                                   Flushing Cemetery
# 19                   St. Paul's Churchyard Cobble Hill
# 20                      Catholic Cemetery, Willamsburg
# 21                 Bay Ridge Methodist Church Cemetery
# 22              Westchester Methodist Church Graveyard
# 23                     St. Andrew's Churchyard, Harlem
# 24                               Resurrection Cemetery
# 171                   Carmine Street Lutheran Cemetery
# 172                             Mount Lebanon Cemetery
# 173             St. John's Cemetery, Greenwich Village
# 174                        Hopper Family Burial Ground
# 175             St. Patrick's old cathedral's cemetery
# 176                     St. Peter's Catholic Graveyard
# 177                     Third Shearith Israel Cemetery
# 178                    Second Shearith Israel Cemetery
# 179                     First Shearith Israel Cemetery
# 180                      Passionist Monastery Cemetery
# 181                      11th Street Catholic Cemetery
# 182                              Johnson Burial Ground
# 183                            French Church of Esprit
# 184                      Strattonport Village Cemetery
# 185                       Indian Cemetery, Little Neck
# 186                      Leverich Family Burial Ground
# 187  The New Burial Place without the gate of the city
# 188                 The old Graveyard of new Amsterdam
#
#     Number of Churches Nearby
# 0                          57
# 1                          53
# 2                           4
# 3                           2
# 4                          34
# 5                          59
# 6                          19
# 7                           8
# 8                          47
# 9                          60
# 10                         60
# 11                         19
# 12                          1
# 13                         45
# 14                         31
# 15                         32
# 16                         48
# 17                          2
# 18                         38
# 19                         40
# 20                         21
# 21                         39
# 22                         34
# 23                         60
# 24                          7
# 25                         13
# 26                         38
# 27                         21
# 28                         60
# 29                         41
# 30                         60
# 31                         41
# 32                          8
# 33                         60
# 34                          1
# 35                         30
# 36                         21
# 37                         60
# 38                         60
# 39                         15
# 40                         22
# 41                         23
# 42                         19
# 43                         44
# 44                         51
# 45                         60
# 46                         37
# 47                         60
# 48                         60
# 49                         14
# 50                          0
# 51                         49
# 52                          0
# 53                          8
# 54                         50
# 55                          9
# 56                          6
# 57                         60
# 58                         16
# 59                         60
# 60                          6
# 61                         60
# 62                         19
# 63                         19
# 64                         60
# 65                         36
# 66                          3
# 67                          4
# 68                         60
# 69                         26
# 70                         33
# 71                         33
# 72                         30
# 73                          5
# 74                         38
# 75                          5
# 76                          9
# 77                         60
# 78                         60
# 79                          1
# 80                         23
# 81                         45
# 82                         60
# 83                         47
# 84                         59
# 85                         13
# 86                         50
# 87                         60
# 88                         15
# 89                         55
# 90                         60
# 91                         60
# 92                         60
# 93                          0
# 94                         60
# 95                         54
# 96                          3
# 97                         43
# 98                         44
# 99                         60
# 100                        42
# 101                         2
# 102                        60
# 103                        60
# 104                        16
# 105                        14
# 106                         6
# 107                         1
# 108                         3
# 109                         8
# 110                         8
# 111                        12
# 112                         8
# 113                         9
# 114                        19
# 115                        31
# 116                        60
# 117                        60
# 118                        60
# 119                        60
# 120                        60
# 121                        60
# 122                        24
# 123                        42
# 124                        23
# 125                        60
# 126                        14
# 127                        60
# 128                        27
# 129                        60
# 130                         7
# 131                        10
# 132                        29
# 133                         3
# 134                         3
# 135                         1
# 136                        12
# 137                        56
# 138                         6
# 139                         6
# 140                         6
# 141                         6
# 142                         3
# 143                        40
# 144                         4
# 145                        17
# 146                        60
# 147                        17
# 148                        10
# 149                        60
# 150                        60
# 151                        39
# 152                        36
# 153                        14
# 154                        33
# 155                        16
# 156                        60
# 157                         0
# 158                         5
# 159                         8
# 160                         8
# 161                        60
# 162                        16
# 163                        12
# 164                         4
# 165                        27
# 166                        15
# 167                        20
# 168                        11
# 169                        42
# 170                        40
# 171                        41
# 172                        13
# 173                        40
# 174                        60
# 175                        60
# 176                        43
# 177                        60
# 178                        60
# 179                        60
# 180                        26
# 181                        60
# 182                         7
# 183                        35
# 184                        15
# 185                        18
# 186                        53
# 187                        34
# 188                        30

# %%
import time
# Making a deep copy of the current filtered dataFrame

def fetch_all_places(api_key, location,place_type, radius =500):
    # Google Places API endpoint
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # Initial parameters for the API request
    params = {
        'key': API_KEY,
        'location': location,
        'radius': radius,
        'type': place_type
    }

    # List to store all places
    places = []
    counter = 0
    while True:
    # Make the API request
      response = requests.get(url, params=params)
      res = response.json()

    # Check if the request was successful
      if res['status'] == 'OK':
        # Extract places
        places.extend([(place['name'], place['vicinity']) for place in res['results']])
        counter += 1
        print("Counter: ", counter)
        # Check for the presence of a 'next_page_token' in the response
        if 'next_page_token' in res:
            params['pagetoken'] = res['next_page_token']
        else:
            break  # No more pages to fetch

        # Important: There is a short delay needed between requests for the next page token to become valid
        time.sleep(2)
      else:
        print("Failed to fetch results:", res['status'])
        break

    return len(places)


#store the churh places close to  a place
places = []
# Update DataFrame with the count of nearby churches
# Assume df is your DataFrame and already imported
for i in range(len(df_exist)):
  row = df_exist.iloc[i]
  lat, lon = row['Latitude'], row['Longitude']
  churches_count = fetch_all_places(api_key, location, place_type, radius)
  df_copy.at[i,'Number of Churches Nearby']= churches_count


# Optionally, save the updated DataFrame
df_exist.to_csv('updated_cemetery_data.csv', index=False)
df_copy.to_csv('updated_cemetery_data.csv', index=False)

# Display the DataFrame for verification
pd.set_option('display.max_rows', None)
# Print every entry in the 'Number of Churches Nearby' column
print(df_copy['Number of Churches Nearby'].to_string())

print(df_copy[['Name', 'Number of Churches Nearby']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-63a597381f01> in <cell line: 2>()
#       1 # Update DataFrame with the count of nearby churches
#       2 for index, row in df_exist.iterrows():
# ----> 3     lat, lon = df_exist['Latitude'], df_exist['Longitude']
#       4     churches_count = get_nearby_churches_count(lat, lon)
#       5     df_exist.at[index, 'Number of Churches Nearby'] = churches_count
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Latitude'

# %%
def get_nearby_churches_count(lat, lon, radius=1000):
    location = f'{lat},{lon}'
    place_type = 'church'

    url = (
        f'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
        f'?location={location}'
        f'&radius={radius}'
        f'&type={place_type}'
        f'&key={API_KEY}'
    )

    response = requests.get(url)
    places = response.json()

    # Count the number of church results returned
    count = len(places.get('results', []))
    return count

get_nearby_churches_count(-74.011873,40.708411)
# Out:
# 0

# %%
df['Latitude']
df['Longitude']
# Out:
# 0     -73.952726
# 1     -74.006439
# 2     -74.147084
# 3     -73.883285
# 4     -74.007490
#          ...
# 184   -73.843246
# 185   -73.736872
# 186   -73.894548
# 187   -74.011873
# 188   -74.013348
# Name: Longitude, Length: 189, dtype: float64
